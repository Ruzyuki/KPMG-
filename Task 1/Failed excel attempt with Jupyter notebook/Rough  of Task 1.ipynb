# %%
import pandas as pd

# %%
df = pd.read_excel("KPMG.xlsx","CustomerDemographic", skiprows=1)
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_9856/2694134924.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype={value.dtype})
#   df = pd.read_excel("KPMG.xlsx","CustomerDemographic", skiprows=1)

# %%
df.isnull().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# default                                302
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %%
kt = df[df["last_name"].isnull()]

# %%
#df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# default                                302
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %%
df[df["last_name"].isnull()]
# Out:
#       customer_id first_name last_name  gender  \
# 3               4     Talbot       NaN    Male
# 66             67     Vernon       NaN    Male
# 105           106       Glyn       NaN    Male
# 138           139        Gar       NaN    Male
# 196           197       Avis       NaN  Female
# ...           ...        ...       ...     ...
# 3884         3885      Asher       NaN    Male
# 3915         3916     Myrtia       NaN  Female
# 3926         3927     Conway       NaN    Male
# 3961         3962     Benoit       NaN    Male
# 3998         3999  Patrizius       NaN    Male
#
#       past_3_years_bike_related_purchases        DOB  \
# 3                                      33 1961-10-03
# 66                                     67 1960-06-14
# 105                                    54 1966-07-03
# 138                                     1 1964-07-28
# 196                                    32 1977-01-27
# ...                                   ...        ...
# ...

# %%
kt
# Out:
#       customer_id first_name last_name  gender  \
# 3               4     Talbot       NaN    Male
# 66             67     Vernon       NaN    Male
# 105           106       Glyn       NaN    Male
# 138           139        Gar       NaN    Male
# 196           197       Avis       NaN  Female
# ...           ...        ...       ...     ...
# 3884         3885      Asher       NaN    Male
# 3915         3916     Myrtia       NaN  Female
# 3926         3927     Conway       NaN    Male
# 3961         3962     Benoit       NaN    Male
# 3998         3999  Patrizius       NaN    Male
#
#       past_3_years_bike_related_purchases        DOB  \
# 3                                      33 1961-10-03
# 66                                     67 1960-06-14
# 105                                    54 1966-07-03
# 138                                     1 1964-07-28
# 196                                    32 1977-01-27
# ...                                   ...        ...
# ...

# %%
df.shape
# Out:
# (4000, 13)

# %%
df["last_name"] = df["last_name"].fillna(1)

# %%
df.isnull().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                                0
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# default                                302
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %%
df['last_name'].value_counts()
# Out:
# 1            125
# Pristnor       3
# Ramsdell       3
# Gimber         2
# Roelofs        2
#             ...
# Whittock       1
# Carwithen      1
# Blas           1
# Dearlove       1
# Oldland        1
# Name: last_name, Length: 3726, dtype: int64

# %%
#df["DOB"] = df["DOB"].dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                                0
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# default                                302
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %%
df.shape
# Out:
# (4000, 13)

# %%
df.dropna(subset = ["DOB"], inplace = True)

# %%
df.isnull().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                                0
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                      0
# job_title                              497
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# default                                215
# owns_car                                 0
# tenure                                   0
# dtype: int64

# %%
df.shape
# Out:
# (3913, 13)
